# %%
import scanpy as sc
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Inital setting for plot size
sc.set_figure_params(dpi=300)
sc.settings.verbosity = 1
sc.logging.print_header()
# Out:
# scanpy==1.9.3 anndata==0.9.1 umap==0.5.3 numpy==1.21.5 scipy==1.10.1 pandas==1.5.3 scikit-learn==1.2.2 statsmodels==0.13.5 python-igraph==0.10.4 pynndescent==0.5.10

# %%
from matplotlib import rcParams
FIGSIZE=(3,3)
rcParams['figure.figsize']=FIGSIZE
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
CD8 = sc.read_h5ad('/home/zhepan/Project/PaperCD8/data/CD8.h5ad')
cd8Tex = sc.read_h5ad('/home/zhepan/Project/PaperCD8/data/CD8Tex.h5ad')

# %%
CD8
# Out:
# AnnData object with n_obs × n_vars = 238134 × 19798
#     obs: 'nCount_RNA', 'nFeature_RNA', 'sample.timepoint', 'treatment.type', 'treatment.efficacy', 'CancerType', 'Study', 'sample.ID', 'sample.Tissue', 'percent.mt', 'RNA_snn_res.2', 'seurat_clusters', 'celltype.major', 'cluster', 'cell.id', 'scibet.celltype', 'scibet.celltype.minor', 'manual.celltype.minor', 'manual.celltype.major', 'S.Score', 'G2M.Score', 'Phase', 'RNA_snn_res.0.2', 'RNA_snn_res.0.3', 'RNA_snn_res.0.4', 'RNA_snn_res.0.5', 'RNA_snn_res.0.6', 'RNA_snn_res.0.7', 'RNA_snn_res.0.8', 'RNA_snn_res.0.9', 'RNA_snn_res.1'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_harmony', 'X_pca', 'X_umap_harmony'

# %%
from colordict import *

# %%
celltype_major_colors_dict = celltype_major_colors()
celltype_minor_colors_dict = celltype_minor_colors()
celltype_Tex_colors_dict = celltype_Tex_colors()

# %%
CD8.obs['celltype_major'] = CD8.obs['manual.celltype.major']
CD8.uns['celltype_major_colors'] = list(celltype_major_colors_dict.values())

# %%
CD8_umap = sc.pl.embedding(CD8,basis='X_umap_harmony',size = 2,
    color=['celltype_major'], title = 'Celltype',
    frameon = False,legend_fontsize=6)
# Out:
# /home/zhepan/miniconda3/envs/scRNA/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
